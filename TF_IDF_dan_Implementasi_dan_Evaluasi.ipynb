# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/dayangalyssa/InfoKilat/main/data/preprocessed_sentences.csv'
df = pd.read_csv(url)

df.head(50)
# Out:
#                                     original_sentence  \
# 0   TEMPO.CO, Jakarta - Anggota Komisi VII DPR RI ...
# 1   "Turut berbela sungkawa terhadap masyarakat si...
# 2   Pertamina harus tanggung jawab," kata dia dala...
# 3   TBBM Plumpang dinilai sebagai salah satu termi...
# 4   "Plumpang menyuplai sekitar 20 persen kebutuha...
# 5   Maka tindakan selanjutnya adalah bagaimana mem...
# 6   Terhitung 2 tahun terakhir ini, kata dia, suda...
# 7   "Menyayangkan terjadinya musibah kebakaran ini...
# 8   Pertamina harus benahi sistem pengamanan dan S...
# 9   Menurutnya pembenahan diperlukan agar Pertamin...
# 10  "Investigasi menyeluruh dan tuntas, serta memi...
# 11  TEMPO.CO, Jakarta - Presiden Joko Widodo atau ...
# 12  Kebakaran besar di lokasi tersebut terjadi pad...
# 13              "Presiden tidak ke Plumpang hari ini.
# 14  Tapi, Presiden sudah berkoordinasi dengan Wapr...
# 15  "Intinya Presiden minta untuk mengutamakan eva...
# 16  Kepala Dinas Penanggulangan Kebakaran dan Peny...
# 17  Dilansir dari Antara, salah seorang warga, Pan...
# 18  Namun, pihak Pertamina mengaku masih menginves...
# 19  "Penyebab kejadian masih dalam proses investig...
# 20  Sementara 50 orang mengalami luka-luka dengan ...
# 21  Badan Penanggulangan Bencana Daerah (BPBD) DKI...
# 22         Mereka tersebar di enam titik pengungsian.
# 23  "Pengungsi info sementara 579 jiwa," demikian ...
# 24  INFO NASIONAL - Wakil Ketua MPR RI Dr. H. M. H...
# 25  Pertemuan tersebut berlangsung di Ruang Kerja ...
# 26  Tapi, hingga kini keputusan tersebut belum bis...
# 27  Kepada HNW, Abdul Rasyid mengatakan, para calo...
# 28  "Keberangkatan ke Mekah, lebih penting dibandi...
# 29  Kami berharap pemerintah hadir dalam perkara i...
# 30  HNW memahami, betapa kecewa dan sedihnya jamaa...
# 31  Persoalan Umroh, menurut HNW kerap dibahas ole...
# 32  Sayangnya persoalan haji lebih mendapat perhat...
# 33  Apalagi, mereka pernah dijanjikan oleh Kemente...
# 34                                                (*)
# 35  TEMPO.CO, Jakarta - Tim Kedokteran dan Kesehat...
# 36  "Pada hari ini, posko DVI sudah menerima 14 ka...
# 37  Tim DVI pun langsung bekerja untuk melakukan i...
# 38  Pada saat kejadian, kata Dedi, tim Dokkes Polr...
# 39  Tim Dokkes Polri juga telah mendirikan posko D...
# 40  "Langkah yang dilakukan hari setelah clear dar...
# 41                  Jumlah anggota sementara 9 orang.
# 42  Alat yang kita gunakan toolkid kebakaran, dron...
# 43  "Mendirikan dapur umum di Pos Polisi oleh Sat ...
# 44  INFO NASIONAL - Ketua MPR RI sekaligus Ketua U...
# 45  Sehingga, dapat menginspirasi klub-klub otomot...
# 46  "Selamat kepada sahabat saya Ahmad Sahroni yan...
# 47  "Dan kompetensi yang dibutuhkan untuk memimpin...
# 48  Firman Santyabudi, Wakapolda Jawa Tengah Brigj...
# 49  Abiyoso Seno Aji, Dirjen Administrasi Hukum Um...
#
#                                    processed_sentence  document_id
# 0   tempo co  jakarta - anggota komisi vii dpr ri ...            0
# 1    bela sungkawa masyarakat sipil dampak  daerah...            0
# 2   pertamina tanggung   terang jakarta sabtu  4 m...            0
# 3   tbbm plumpang nilai salah terminal bbm penting...            0
# 4    plumpang suplai 20 persen butuh bbm hari  25 ...            0
# 5   tindak suplai bbm ganggu   kata rofik singgung...            0
# 6   hitung 2   5 fasilitas migas milik pertamina a...            0
# 7    sayang musibah bakar  insiden bakar kali fasi...            0
# 8   pertamina benah sistem aman sop   dia rofik ha...            0
# 9   turut benah pertamina abai aspek aman fasilita...            0
# 10   investigasi tuntas  komitmen pertamina baik s...            0
# 11  tempo co  jakarta - presiden joko widodo jokow...            1
# 12  bakar lokasi jumat malam  3 maret 2023  akibat...            1
# 13                                 presiden plumpang             1
# 14   presiden koordinasi wapres tinjau   deputi bi...            1
# 15   inti presiden utama evakuasi korban tangan wa...            1
# 16  kepala dinas tanggulang bakar selamat dki jaka...            1
# 17  lansir  salah warga  pandi  bau bensin santer ...            1
# 18           pertamina aku investigasi sebab insiden             1
# 19   sebab jadi proses investigasi   area manager ...            1
# 20  50 orang alami luka tingkat parah api sambar k...            1
# 21  badan tanggulang bencana daerah  bpbd  dki jak...            1
# 22                            sebar enam titik ungsi             1
# 23   ungsi 579 jiwa   terang bpbd dki jakarta  sab...            1
# 24  - wakil ketua mpr ri dr h m hidayat nur wahid ...            2
# 25  temu ruang kerja wakil ketua mpr gedung nusant...            2
# 26   putus eksekusi bahkan  jaksa negeri  kejar  d...            2
# 27  hnw  abdul rasyid  calon jamaah umroh harap be...            2
# 28   berangkat mekah  banding terima kembali biaya...            2
# 29  harap perintah hadir perkara  bertanggungjawab...            2
# 30  hnw paham  betapa kecewa sedih jamaah gagal be...            2
# 31  umroh  hnw kerap bahas komisi viii dpr ri ment...            2
# 32  sayang haji perhati banding ibadah umroh ini a...            2
# 33   janji menteri agama  berangkat umroh hukum in...            2
# 34                                                               2
# 35  tempo co  jakarta - tim dokter sehat  dokkes  ...            3
# 36               posko dvi terima 14 kantong jenazah             3
# 37  tim dvi langsung identifikasi korban   kepala ...            3
# 38  jadi  dedi  tim dokkes polri kirim 5 ambulans ...            3
# 39  tim dokkes polri diri posko dvi rumah sakit po...            3
# 40   langkah clear hse  health safety environment ...            3
# 41                                   anggota 9 orang             3
# 42  alat toolkid bakar  drone  alat ambil sampel a...            3
# 43   diri dapur pos polisi sat brimobda pmj bantu ...            3
# 44  - ketua mpr ri ketua ikat motor  imi  wakil ke...            4
# 45   inspirasi klub otomotif kontribusi baik hidup...            4
# 46   selamat sahabat ahmad sahroni pilih ketua hdc...            4
# 47   kompetensi butuh pimpin maju organisasi hdci ...            4
# 48     firman santyabudi  wakapolda jawa brigjen pol             4
# 49  abiyoso seno aji  dirjen administrasi hukum ke...            4

# %%
# Cek jumlah dokumen unik
num_docs = df['document_id'].nunique()
print(f"Jumlah document_id unik: {num_docs}")
# Out:
# Jumlah document_id unik: 50

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Ambil hanya document_id = 0
doc_df = df[df['document_id'] == 0].reset_index(drop=True)

# Ekstrak teks per kalimat
kalimat_list = doc_df['processed_sentence'].tolist()

# Inisialisasi CountVectorizer
vectorizer = CountVectorizer()

# Hitung term frequency per kalimat
X = vectorizer.fit_transform(kalimat_list)

# Ubah jadi DataFrame
tf_df = pd.DataFrame(X.toarray().T,  # transpose agar rows = terms, columns = kalimat
                     index=vectorizer.get_feature_names_out(),
                     columns=[f"Kalimat {i+1}" for i in range(len(kalimat_list))])

# Tambahkan kolom tf total
tf_df["tf"] = tf_df.sum(axis=1)

# Urutkan berdasarkan tf tertinggi (opsional)
tf_df = tf_df.sort_values("tf", ascending=False)

# Tampilkan hasil
tf_df.head()
# Out:
#            Kalimat 1  Kalimat 2  Kalimat 3  Kalimat 4  Kalimat 5  Kalimat 6  \
# pertamina          0          0          2          1          1          1
# bakar              1          0          2          1          0          0
# aman               0          0          1          1          0          0
# bbm                0          0          1          1          1          1
# plumpang           1          0          1          1          1          0
#
#            Kalimat 7  Kalimat 8  Kalimat 9  Kalimat 10  Kalimat 11  tf
# pertamina          1          0          2           1           3  12
# bakar              1          2          0           0           1   8
# aman               0          0          3           1           2   8
# bbm                0          0          0           0           2   6
# plumpang           0          0          0           0           1   5

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

tf_dict = {}

for doc_id in range(51):
    doc_df = df[df['document_id'] == doc_id].reset_index(drop=True)

    if doc_df.empty:
        continue

    # Drop NaN di kolom processed_sentence dan pastikan semuanya string
    kalimat_list = doc_df['processed_sentence'].dropna().astype(str).tolist()

    # Skip jika tidak ada kalimat valid
    if len(kalimat_list) == 0:
        continue

    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(kalimat_list)

    tf_df = pd.DataFrame(X.toarray().T,
                         index=vectorizer.get_feature_names_out(),
                         columns=[f"Kalimat {i+1}" for i in range(len(kalimat_list))])

    tf_df["tf"] = tf_df.sum(axis=1)
    tf_df = tf_df.sort_values("tf", ascending=False)

    tf_dict[doc_id] = tf_df

# %%
display(tf_dict[0])
# Out:
#            Kalimat 1  Kalimat 2  Kalimat 3  Kalimat 4  Kalimat 5  Kalimat 6  \
# pertamina          0          0          2          1          1          1
# bakar              1          0          2          1          0          0
# aman               0          0          1          1          0          0
# bbm                0          0          1          1          1          1
# plumpang           1          0          1          1          1          0
# ...              ...        ...        ...        ...        ...        ...
# ujar               0          0          0          0          0          0
# ulang              0          0          0          0          0          0
# utara              1          0          0          0          0          0
# vii                1          0          0          0          0          0
# warga              0          0          1          0          0          0
#
#            Kalimat 7  Kalimat 8  Kalimat 9  Kalimat 10  Kalimat 11  tf
# pertamina          1          0          2           1           3  12
# bakar              1          2          0           0           1   8
# aman               0          0          3           1           2   8
# bbm                0          0          0           0           2   6
# plumpang           0          0          0           0           1   5
# ...              ...        ...        ...         ...         ...  ..
# ujar               0          0          0           0           1   1
# ulang              0          1          0           0           0   1
# utara              0          0          0           0           0   1
# vii                0          0          0           0           0   1
# warga              0          0          0           0           0   1
#
# [93 rows x 12 columns]

# %%
import numpy as np
import warnings

# Nonaktifkan warning untuk applymap
warnings.filterwarnings("ignore", category=FutureWarning)

# Dictionary baru untuk menyimpan hasil weight_tf
weight_tf_dict = {}

for doc_id, tf_df in tf_dict.items():
    # Salin tf_df tanpa kolom "tf"
    tf_only = tf_df.drop(columns=["tf"]).copy()

    # Hitung weight_tf: 1 + log10(tf), jika tf > 0
    weight_tf = tf_only.applymap(lambda x: 1 + np.log10(x) if x > 0 else 0)

    # Tambahkan baris ws (jumlah bobot per kalimat)
    weight_tf.loc["Ws"] = weight_tf.sum(axis=0)

    # (Opsional) Tambahkan kolom W_tf (jumlah bobot per term)
    weight_tf["W_tf"] = weight_tf.sum(axis=1)

    # Simpan ke dictionary
    weight_tf_dict[doc_id] = weight_tf

# Contoh tampilkan hasil untuk document_id = 4
display(weight_tf_dict[1].round(4))
# Out:
#           Kalimat 1  Kalimat 2  Kalimat 3  Kalimat 4  Kalimat 5  Kalimat 6  \
# bakar        1.0000        1.0        0.0     0.0000      1.000     1.4771
# jakarta      1.3010        0.0        0.0     1.0000      1.000     1.0000
# presiden     1.3010        0.0        1.0     1.3010      1.000     0.0000
# warga        0.0000        1.0        0.0     0.0000      1.000     1.0000
# plumpang     1.0000        0.0        1.0     0.0000      1.000     0.0000
# ...             ...        ...        ...        ...        ...        ...
# wakil        1.0000        0.0        0.0     0.0000      0.000     0.0000
# wapres       0.0000        0.0        0.0     1.0000      0.000     0.0000
# wib          0.0000        0.0        0.0     0.0000      1.000     0.0000
# widodo       1.0000        0.0        0.0     0.0000      0.000     0.0000
# Ws          20.6021       11.0        2.0    42.6021     22.301    19.7782
#
#           Kalimat 7  Kalimat 8  Kalimat 9  Kalimat 10  Kalimat 11  Kalimat 12  \
# bakar           1.0        0.0     1.0000       0.000         1.0         0.0
# jakarta         0.0        0.0     1.0000       0.000         1.0         0.0
# presiden        0.0        0.0     0.0000       0.000         0.0         0.0
# warga           1.0        0.0     0.0000       1.000         1.0         0.0
# plumpang        0.0        0.0     1.0000       0.000         0.0         0.0
# ...             ...        ...        ...         ...         ...         ...
# wakil           0.0        0.0     0.0000       0.000         0.0         0.0
# wapres          0.0        0.0     0.0000       0.000         0.0         0.0
# wib             0.0        0.0     0.0000       0.000         0.0         0.0
# widodo          0.0        0.0     0.0000       0.000         0.0         0.0
# Ws             15.0        5.0    35.6021      16.301        14.0         4.0
#
#           Kalimat 13      W_tf
# bakar          0.000    7.4771
# jakarta        1.000    7.3010
# presiden       0.000    4.6021
# warga          0.000    6.0000
# plumpang       1.000    5.0000
# ...              ...       ...
# wakil          0.000    1.0000
# wapres         0.000    1.0000
# wib            0.000    1.0000
# widodo         0.000    1.0000
# Ws            20.301  228.4874
#
# [153 rows x 14 columns]

# %%
# Dictionary untuk menyimpan ringkasan 3 kalimat asli teratas per dokumen
top3_summary_dict = {}

for doc_id in range(51):
    if doc_id not in weight_tf_dict:
        continue

    weight_tf = weight_tf_dict[doc_id]

    # Ambil baris Ws dan urutkan dari yang terbesar
    ws_series = weight_tf.loc["Ws"].drop("W_tf").sort_values(ascending=False)

    # Ambil 3 kalimat teratas berdasarkan nilai Ws
    top_kalimat_cols = ws_series.head(3).index.tolist()

    # Urutkan kalimat-kalimat ini berdasarkan indeks kalimat (misal 'Kalimat 2' → 2)
    sorted_kalimat_cols = sorted(top_kalimat_cols, key=lambda x: int(x.split()[-1]))

    # Ambil dataframe asli untuk document_id ini
    doc_df = df[df['document_id'] == doc_id].reset_index(drop=True)

    # Ambil kalimat asli berdasarkan indeks kalimat
    selected_original_sentences = []
    for kal_col in sorted_kalimat_cols:
        kal_index = int(kal_col.split()[-1]) - 1  # 'Kalimat 2' -> index 1
        if kal_index < len(doc_df):
            selected_original_sentences.append(doc_df.loc[kal_index, 'original_sentence'])

    # Simpan hasil ringkasan
    top3_summary_dict[doc_id] = selected_original_sentences

# %%
# Contoh output: ringkasan untuk document_id = 0
print("Ringkasan 3 kalimat teratas untuk document_id 0:\n")
for i, kalimat in enumerate(top3_summary_dict[1], 1):
    print(f"{i}. {kalimat}")
# Out:
# Ringkasan 3 kalimat teratas untuk document_id 0:
#
# 1. Tapi, Presiden sudah berkoordinasi dengan Wapres yang akan meninjau hari ini," ujar Deputi Bidang Protokol, Pers, dan Media Sekretariat Presiden Bey Machmudin saat dihubungi, Sabtu, 4 Februari 2023.Selain memerintahkan Ma'ruf Amin, Bey menyebut Jokowi juga telah memberikan arahan kepada Kapolri Jenderal Listyo Sigit Prabowo, Menteri BUMN Erick Thohir, dan Penjabat Gubernur DKI Jakarta Heru Budi Hartono soal kunjungan ke lokasi.
# 2. "Intinya Presiden minta untuk mengutamakan evakuasi korban dan penanganan warga terdampak," kata Bey.Kronologi KebakaranDepo Pertamina di Plumpang, Jakarta Utara, terbakar pada Jumat malam, 3 Maret 2023, pukul 20.20 WIB.
# 3. "Penyebab kejadian masih dalam proses investigasi," kata Area Manager Communication, Relation & CSR Pertamina Patra Niaga Regional Jawa Bagian Barat Eko Kristiawan.Eko juga menambahkan pihaknya saat ini fokus pada penanganan kebakaran pipa penerimaan BBM di Integrated Terminal BBM Jakarta, Plumpang.Setidaknya 17 orang dilaporkan meninggal dunia akibat insiden ini.

# %% [markdown]
# #Implementasi Model

# %%
# !pip install transformers sentencepiece --quiet

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load tokenizer dan model
tokenizer = AutoTokenizer.from_pretrained("cahya/bert2bert-indonesian-summarization")
model = AutoModelForSeq2SeqLM.from_pretrained("cahya/bert2bert-indonesian-summarization")

# Fungsi untuk merangkum teks
def summarize(text):
    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(inputs, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# Contoh penggunaan
text = "Masukkan teks panjang dalam bahasa Indonesia di sini untuk dirangkum."
print(summarize(text))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/999M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/999M [00:00<?, ?B/s]
# masukkan teks panjang dalam bahasa indonesia di bahasa indonesia, rendarizetta merilis buku terbaru dalam bahasa inggris. dalam buku ini, summarize mengangkat isu tanah air di tanah air yang sedang berbenah.

# %%
def ringkas_teks_indo(text, max_input_length=512, max_output_length=100):
    # Tambah prefix khusus untuk tugas summarization
    input_text = "ringkasan: " + text
    inputs = tokenizer.encode(input_text, return_tensors="pt", max_length=max_input_length, truncation=True)

    summary_ids = model.generate(inputs, max_length=max_output_length, min_length=20, length_penalty=2.0, num_beams=4, early_stopping=True)

    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
import re

# Bersihkan teks
def bersihkan(text):
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'<.*?>', '', text)
    return text.strip()

# Simpan hasil ringkasan
indot5_summary_dict = {}

for doc_id in df['document_id'].unique():
    doc_text = ' '.join(df[df['document_id'] == doc_id]['original_sentence'].dropna().astype(str).tolist())
    doc_text = bersihkan(doc_text)

    if len(doc_text) < 50:
        continue

    try:
        summary = ringkas_teks_indo(doc_text[:1024])  # batas aman
        indot5_summary_dict[doc_id] = summary
    except Exception as e:
        indot5_summary_dict[doc_id] = "(Ringkasan gagal)"
# Out:
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.

# %%
indot5_summary_df = pd.DataFrame.from_dict(indot5_summary_dict, orient='index', columns=['indot5_summary'])
indot5_summary_df.reset_index(inplace=True)
indot5_summary_df.rename(columns={'index': 'document_id'}, inplace=True)

display(indot5_summary_df.head(100))
# Out:
#     document_id                                     indot5_summary
# 0             0  anggota komisi vii dpr ri rofik hananto menyay...
# 1             1  kebakaran depo pertamina di plumpang, jakarta ...
# 2             2  delegasi paguyuban first travel indonesia mene...
# 3             3  tim kedokteran dan kesehatan ( dokkes ) polri ...
# 4             4  ketua mpr ri sekaligus ketua umum ikatan motor...
# 5             5  wakil presiden ma ruf meninjau lokasi kebakara...
# 6             6  menteri keuangan ri sri mulyani indrawati berk...
# 7             7  keputusan pengadilan negeri jakarta pusat meng...
# 8             8  markas besar kepolisian republik indonesia tur...
# 9             9  kawasan penyangga depo pertamina plumpang, jak...
# 10           10  presiden joko widodo memerintahkan menteri bum...
# 11           11  komisi yudisial diminta menggali motif hakim p...
# 12           12  ketua umum partai nasional demokrat surya palo...
# 13           13  ketua mpr ri yandri susanto optimis kpu dapat ...
# 14           14  prabowo subianto mengakui adanya pembicaraan s...
# 15           15  komnas ham akan menurunkan tim untuk menginves...
# 16           16  pengadilan negeri atau pn jakarta pusat menget...
# 17           17  wakil presiden ma ruf amin mengusulkan agar de...
# 18           18  kpu mempersiapkan memori banding terhadap putu...
# 19           19  pertemuan pm fiji sitivani rabuka dengan pimpi...
# 20           20  majelis hakim pengadilan negeri jakarta pusat ...
# 21           21  direktur eksekutif perludem khoirunnisa agusty...
# 22           22  wakil ketua mpr ri, lestari moerdijat, mengata...
# 23           23  pihak - pihak yang berupaya melakukan penundaa...
# 24           24  ade irfan pulungan, tenaga ahli utama kantor s...
# 25           25  menteri pertanian syahrul yasin limpo meminta ...
# 26           26  sekjen psi dea tunggaesti mengatakan gugatan d...
# 27           27  kpk menyatakan telah mengetahui laporan mengen...
# 28           28  menurut peneliti pusat kajian antikorupsi zaen...
# 29           29  partai ummat mustofa nahrawardaya menawarkan i...
# 30           30  prabowo subianto secara tegas menolak wacana u...
# 31           31  mentan syahrul yasin limpo melaksanakan panen ...
# 32           32  kpk akan melakukan pemeriksaan terhadap mantan...
# 33           33  perpindahan kader partainya ke partai ummat ta...
# 34           34  pengamat politik adi prayitno membeberkan alas...
# 35           35  dalam pertemuan tersebut, menurut laode muhamm...
# 36           36  menurut pakar hukum tata negara feri amsari, p...
# 37           37  menteri bumn erick thohir mengunjungi korban k...
# 38           38  pasangan anies baswedan - agus harimurti yudho...
# 39           39  lemahnya sistem dan mekanisme lhkpn di indones...
# 40           40  kapolri jenderal listyo sigit prabowo meminta ...
# 41           41  pasangan anies baswedan - agus harimurti yudho...
# 42           42  menteri pertanian syahrul yasin limpo, kembali...
# 43           43  kementerian pertanian memastikan proses perizi...
# 44           44  para pengusaha yang tergabung dalam gabungan p...
# 45           45  menurut menteri pendayagunaan aparatur negara ...
# 46           46  kpk menjelaskan alasan mengapa tidak ada tinda...
# 47           47  kapolri jenderal listyo sigit prabowo menemui ...
# 48           48  info nasional bpjs kesehatan berperan dalam ha...
# 49           49  menneg bumn erick thohir menargetkan bumn menj...

# %%
indot5_summary_df.to_csv('indot5_summary.csv', index=False)
full_df = pd.read_csv('indot5_summary.csv')
print(full_df)
# Out:
#     document_id                                     indot5_summary
# 0             0  anggota komisi vii dpr ri rofik hananto menyay...
# 1             1  kebakaran depo pertamina di plumpang, jakarta ...
# 2             2  delegasi paguyuban first travel indonesia mene...
# 3             3  tim kedokteran dan kesehatan ( dokkes ) polri ...
# 4             4  ketua mpr ri sekaligus ketua umum ikatan motor...
# 5             5  wakil presiden ma ruf meninjau lokasi kebakara...
# 6             6  menteri keuangan ri sri mulyani indrawati berk...
# 7             7  keputusan pengadilan negeri jakarta pusat meng...
# 8             8  markas besar kepolisian republik indonesia tur...
# 9             9  kawasan penyangga depo pertamina plumpang, jak...
# 10           10  presiden joko widodo memerintahkan menteri bum...
# 11           11  komisi yudisial diminta menggali motif hakim p...
# 12           12  ketua umum partai nasional demokrat surya palo...
# 13           13  ketua mpr ri yandri susanto optimis kpu dapat ...
# 14           14  prabowo subianto mengakui adanya pembicaraan s...
# 15           15  komnas ham akan menurunkan tim untuk menginves...
# 16           16  pengadilan negeri atau pn jakarta pusat menget...
# 17           17  wakil presiden ma ruf amin mengusulkan agar de...
# 18           18  kpu mempersiapkan memori banding terhadap putu...
# 19           19  pertemuan pm fiji sitivani rabuka dengan pimpi...
# 20           20  majelis hakim pengadilan negeri jakarta pusat ...
# 21           21  direktur eksekutif perludem khoirunnisa agusty...
# 22           22  wakil ketua mpr ri, lestari moerdijat, mengata...
# 23           23  pihak - pihak yang berupaya melakukan penundaa...
# 24           24  ade irfan pulungan, tenaga ahli utama kantor s...
# 25           25  menteri pertanian syahrul yasin limpo meminta ...
# 26           26  sekjen psi dea tunggaesti mengatakan gugatan d...
# 27           27  kpk menyatakan telah mengetahui laporan mengen...
# 28           28  menurut peneliti pusat kajian antikorupsi zaen...
# 29           29  partai ummat mustofa nahrawardaya menawarkan i...
# 30           30  prabowo subianto secara tegas menolak wacana u...
# 31           31  mentan syahrul yasin limpo melaksanakan panen ...
# 32           32  kpk akan melakukan pemeriksaan terhadap mantan...
# 33           33  perpindahan kader partainya ke partai ummat ta...
# 34           34  pengamat politik adi prayitno membeberkan alas...
# 35           35  dalam pertemuan tersebut, menurut laode muhamm...
# 36           36  menurut pakar hukum tata negara feri amsari, p...
# 37           37  menteri bumn erick thohir mengunjungi korban k...
# 38           38  pasangan anies baswedan - agus harimurti yudho...
# 39           39  lemahnya sistem dan mekanisme lhkpn di indones...
# 40           40  kapolri jenderal listyo sigit prabowo meminta ...
# 41           41  pasangan anies baswedan - agus harimurti yudho...
# 42           42  menteri pertanian syahrul yasin limpo, kembali...
# 43           43  kementerian pertanian memastikan proses perizi...
# 44           44  para pengusaha yang tergabung dalam gabungan p...
# 45           45  menurut menteri pendayagunaan aparatur negara ...
# 46           46  kpk menjelaskan alasan mengapa tidak ada tinda...
# 47           47  kapolri jenderal listyo sigit prabowo menemui ...
# 48           48  info nasional bpjs kesehatan berperan dalam ha...
# 49           49  menneg bumn erick thohir menargetkan bumn menj...

# %% [markdown]
# ## Evaluasi

# %%
# !pip install -q scikit-learn pandas

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
manual_url = "https://docs.google.com/spreadsheets/d/1zcNv1AcX6HwV6Bsj_si15dez7PAKJWi6Up9z9Yy9XeM/export?format=csv"
manual_df = pd.read_csv(manual_url)
manual_df.columns
# Out:
# Index(['document_id', 'manual_summary'], dtype='object')

# %%
# Pastikan document_id bertipe string
manual_df['document_id'] = manual_df['document_id'].astype(str)
full_df['document_id'] = full_df['document_id'].astype(str)

# Merge berdasarkan document_id
merged_df = pd.merge(full_df, manual_df[['document_id', 'manual_summary']], on='document_id', how='inner')

# %%
def get_similarity(row):
    texts = [str(row['indot5_summary']), str(row['manual_summary'])]
    tfidf = TfidfVectorizer().fit_transform(texts)
    return cosine_similarity(tfidf[0:1], tfidf[1:2])[0][0]

merged_df['cosine_similarity'] = merged_df.apply(get_similarity, axis=1)

# %%
merged_df[['document_id', 'indot5_summary', 'manual_summary', 'cosine_similarity']].head(50)
# Out:
#    document_id                                     indot5_summary  \
# 0            0  anggota komisi vii dpr ri rofik hananto menyay...
# 1            1  kebakaran depo pertamina di plumpang, jakarta ...
# 2            2  delegasi paguyuban first travel indonesia mene...
# 3            3  tim kedokteran dan kesehatan ( dokkes ) polri ...
# 4            4  ketua mpr ri sekaligus ketua umum ikatan motor...
# 5            5  wakil presiden ma ruf meninjau lokasi kebakara...
# 6            6  menteri keuangan ri sri mulyani indrawati berk...
# 7            7  keputusan pengadilan negeri jakarta pusat meng...
# 8            8  markas besar kepolisian republik indonesia tur...
# 9            9  kawasan penyangga depo pertamina plumpang, jak...
# 10          10  presiden joko widodo memerintahkan menteri bum...
# 11          11  komisi yudisial diminta menggali motif hakim p...
# 12          12  ketua umum partai nasional demokrat surya palo...
# 13          13  ketua mpr ri yandri susanto optimis kpu dapat ...
# 14          14  prabowo subianto mengakui adanya pembicaraan s...
# 15          15  komnas ham akan menurunkan tim untuk menginves...
# 16          16  pengadilan negeri atau pn jakarta pusat menget...
# 17          17  wakil presiden ma ruf amin mengusulkan agar de...
# 18          18  kpu mempersiapkan memori banding terhadap putu...
# 19          19  pertemuan pm fiji sitivani rabuka dengan pimpi...
# 20          20  majelis hakim pengadilan negeri jakarta pusat ...
# 21          21  direktur eksekutif perludem khoirunnisa agusty...
# 22          22  wakil ketua mpr ri, lestari moerdijat, mengata...
# 23          23  pihak - pihak yang berupaya melakukan penundaa...
# 24          24  ade irfan pulungan, tenaga ahli utama kantor s...
# 25          25  menteri pertanian syahrul yasin limpo meminta ...
# 26          26  sekjen psi dea tunggaesti mengatakan gugatan d...
# 27          27  kpk menyatakan telah mengetahui laporan mengen...
# 28          28  menurut peneliti pusat kajian antikorupsi zaen...
# 29          29  partai ummat mustofa nahrawardaya menawarkan i...
# 30          30  prabowo subianto secara tegas menolak wacana u...
# 31          31  mentan syahrul yasin limpo melaksanakan panen ...
# 32          32  kpk akan melakukan pemeriksaan terhadap mantan...
# 33          33  perpindahan kader partainya ke partai ummat ta...
# 34          34  pengamat politik adi prayitno membeberkan alas...
# 35          35  dalam pertemuan tersebut, menurut laode muhamm...
# 36          36  menurut pakar hukum tata negara feri amsari, p...
# 37          37  menteri bumn erick thohir mengunjungi korban k...
# 38          38  pasangan anies baswedan - agus harimurti yudho...
# 39          39  lemahnya sistem dan mekanisme lhkpn di indones...
# 40          40  kapolri jenderal listyo sigit prabowo meminta ...
# 41          41  pasangan anies baswedan - agus harimurti yudho...
# 42          42  menteri pertanian syahrul yasin limpo, kembali...
# 43          43  kementerian pertanian memastikan proses perizi...
# 44          44  para pengusaha yang tergabung dalam gabungan p...
# 45          45  menurut menteri pendayagunaan aparatur negara ...
# 46          46  kpk menjelaskan alasan mengapa tidak ada tinda...
# 47          47  kapolri jenderal listyo sigit prabowo menemui ...
# 48          48  info nasional bpjs kesehatan berperan dalam ha...
# 49          49  menneg bumn erick thohir menargetkan bumn menj...
#
#                                        manual_summary  cosine_similarity
# 0   Anggota Komisi VII DPR RI Rofik Hananto menyay...           0.712392
# 1   Presiden Joko Widodo atau Jokowi memerintahkan...           0.233199
# 2   Wakil Ketua MPR RI Dr. H. M. Hidayat Nur Wahid...           0.207144
# 3   Tim Kedokteran dan Kesehatan (Dokkes) Polri te...           1.000000
# 4   Ketua MPR RI sekaligus Ketua Umum Ikatan Motor...           1.000000
# 5   Pada 3 Maret 2023, kebakaran hebat melanda Dep...           0.405408
# 6   Memperingati 14 tahun PT Sarana Multi Infrastr...           0.310782
# 7   Pengadilan Negeri atau PN Jakarta Pusat memutu...           0.154640
# 8   Markas Besar Kepolisian Republik Indonesia tur...           0.593011
# 9   Buffer zone atau kawasan penyangga yang memisa...           0.516214
# 10  Menteri BUMN Erick Thohir, Penjabat Gubernur D...           0.583622
# 11  Peneliti Pusat Studi Hukum dan Kebijakan (PSHK...           0.268790
# 12  Ketua Umum Partai Nasional Demokrat (Nasdem) S...           0.593337
# 13  Wakil Ketua MPR RI Yandri Susanto optimis Komi...           0.415696
# 14  Ketua Umum Partai Gerindra, Prabowo Subianto, ...           0.548347
# 15  Komisi Nasional Hak Asasi Manusia akan menurun...           0.346480
# 16  Pengadilan Negeri Jakarta Pusat mengabulkan gu...           0.266924
# 17  Wakil Presiden Ma'ruf Amin mengusulkan agar de...           0.716411
# 18  Komisi Pemilihan Umum mempersiapkan memori ban...           0.360390
# 19  Pengamat hubungan internasional Teuku Rezasyah...           0.541246
# 20  Hakim Oyong, yang sebelumnya menjatuhkan vonis...           0.218406
# 21  Perkumpulan Pemilu untuk Demokrasi (Perludem) ...           0.146462
# 22  Upaya pengembangan pariwisata di kawasan timur...           0.196925
# 23  Sekretaris Jenderal PDI Perjuangan Hasto Krist...           0.646230
# 24  Founder Lembaga Survei Kelompok Kajian dan Dis...           0.142368
# 25  Menteri Pertanian Syahrul Yasin Limpo meminta ...           0.982708
# 26  Putusan Penundaan Pemilu 2024, Tenaga Ahli KSP...           0.290428
# 27  Komisi Pemberantasan Korupsi (KPK) menyatakan ...           0.899100
# 28  Harta Rafael Alun Dianggap Tak Wajar, Pegiat A...           0.225496
# 29  Putusan Penundaan Pemilu 2024, Partai Ummat: J...           0.374841
# 30  Prabowo Subianto Tolak Pasangkan Sandiaga Uno ...           0.809005
# 31  Mentan dan Wamendag Lepas Pasokan Bawang Merah...           0.258932
# 32  KPK Akan Periksa Eko Darmanto Komisi Pemberant...           0.530351
# 33  Kadernya Pindah ke Partai Ummat Wakil Ketua Um...           0.624960
# 34  Banyak Politikus Pindah Parpol Menjelang Pemil...           0.696488
# 35  Sri Mulyani Segera Lancarkan Reformasi Jilid I...           0.714064
# 36  PN Jakpus Putuskan Penundaan Pemilu, Pakar Huk...           0.731971
# 37  Kunjungi Korban Kebakaran Depo Pertamina Plump...           0.770712
# 38  Direktur Eksekutif Voxpol Center Reseach and C...           0.598914
# 39  Ketidakefektifan LHKPN menunjukkan masih rapuh...           0.110797
# 40  Kapolri Jenderal Listyo Sigit Prabowo meminta ...           0.966489
# 41  Direktur Eksekutif Voxpol Center Reseach and C...           0.598914
# 42  Menteri Pertanian Syahrul Yasin Limpo, kembali...           0.811154
# 43  Kementerian Pertanian memastikan proses perizi...           1.000000
# 44  Para pengusaha yang tergabung dalam Gabungan P...           0.852738
# 45  Menteri Pendayagunaan Aparatur Negara dan Refo...           0.714873
# 46   Komisi Pemberantasan Korupsi atau KPK menjela...           0.556994
# 47  Kapolri Jenderal Listyo Sigit Prabowo menemui ...           0.554944
# 48  BPJS Kesehatan berperan dalam hal memberikan p...           0.937362
# 49  Menteri Badan Usaha Milik Negara (BUMN) Erick ...           0.496459

# %%
average_cosine = merged_df['cosine_similarity'].mean()
average_cosine = average_cosine*100
print(f"Average Cosine Similarity: {average_cosine:.0f}%")
# Out:
# Average Cosine Similarity: 54%
